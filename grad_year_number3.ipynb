# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("grad_number3.csv")

# %%
df.head()
# Out:
#      id            name                    email Grad_Year  \
# 0   213       Lina Lina       l.lee23@aus.school      None
# 1   239     Scarlet Kim  scarletkim341@gmail.com      2022
# 2  1509      Sara Sindi       jps0085@jps.edu.sa      2021
# 3  1530   Lamar Agabawi       jps0825@jps.edu.sa      2022
# 4  1534  KHALID ALJUAID       jps0280@jps.edu.sa      2022
#
#                                               name.1     millieCode  \
# 0                   American United School of Kuwait  APO-KW-683108
# 1  St. Joseph's Institution International School ...  IBO-MY-051304
# 2                Jeddah Private Int'l Schools (JPIS)  MLO-SA-000303
# 3                Jeddah Private Int'l Schools (JPIS)  MLO-SA-000303
# 4                Jeddah Private Int'l Schools (JPIS)  MLO-SA-000303
#
#    Total_Score  Multiple_Attempts_At_Test?      Parent_Name  \
# 0       1600.0                        True              NaN
# 1       1600.0                        True              NaN
# 2       1600.0                        True    Ghada Gandeel
# 3       1600.0                        True       Soad Nazar
# 4       1600.0                        True  HUTHLUL ALJUAID
#
#              Parent Email  ...  Matched By New Millie Code?  \
# 0                    None  ...                         True
# 1                    None  ...                         True
# 2      dodo.gag@gmail.com  ...                         True
# 3  suad_nazer@hotmail.com  ...                         True
# 4      hathloul66@htce.sa  ...                         True
#
#   Matched By Old Millie Code? parent_name1 parent_name2 parent_whatsapp  \
# 0                         NaN          NaN          NaN             NaN
# 1                         NaN          NaN          NaN             NaN
# 2                         NaN        Ghada      Gandeel             NaN
# 3                         NaN         Soad        Nazar             NaN
# 4                         NaN      HUTHLUL      ALJUAID             NaN
#
#   student_whatsapp parent_whatsapp_cleaned student_whatsapp_cleaned  \
# 0      96551764687                     NaN           +965 517 64687
# 1          #ERROR!                     NaN                      NaN
# 2              NaN                     NaN                      NaN
# 3              NaN                     NaN                      NaN
# 4              NaN                     NaN                      NaN
#
#   parent_parsed_country  student_parsed_country
# 0                   NaN                  Kuwait
# 1                   NaN                     NaN
# 2                   NaN                     NaN
# 3                   NaN                     NaN
# 4                   NaN                     NaN
#
# [5 rows x 29 columns]

# %%
df["Grad_Year"].replace(np.NaN, -1, inplace = True)
df["Grad_Year"].replace("None", -1, inplace = True)

# %%
grad_year = []
for i in df["Grad_Year"]:
    grad_year.append(int(i))
df["Grad_Year"] = grad_year

# %% [markdown]
# count = 0
# for i in df["Grad_Year"]:
#     if i == -1:
#         count += 1
# print(count)

# %%
df.insert(4,'Grad_Year_New',"")

# %%
email_dict = {}
email_lst = df['email'].to_list()

handle_lst = []
domain_lst = []
for i in range(len(email_lst)):
    email = str(email_lst[i])
    e = email.split('@')
    handle, domain = e[0], e[-1]
    handle_lst.append(handle)
    domain_lst.append(domain)
    
    if domain not in email_dict:
        email_dict[domain] = []
    email_dict[domain].append(handle)

# %%
df.insert(3, "Handle", handle_lst)
df.insert(4, "Domain", domain_lst)

# %%
df_email = pd.DataFrame.from_dict(email_dict, orient = 'index')
df_email.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 274 entries, aus.school to taism.com
# Columns: 1896 entries, 0 to 1895
# dtypes: object(1896)
# memory usage: 4.0+ MB

# %%
df_email.to_csv("email_df_number3.csv") #stop here

# %%
df.loc[df["Domain"] == "bels.bilkent.com"]
# Out:
#        id               name                       email     Handle  \
# 2609  688  Ismail Enes Budak  ibudak.24@bels.bilkent.com  ibudak.24
#
#                 Domain  Grad_Year Grad_Year_New  \
# 2609  bels.bilkent.com         -1
#
#                                  name.1 millieCode  Total_Score  ...  \
# 2609  Bilkent Erzurum Laboratory School        NaN          0.0  ...
#
#       Matched By New Millie Code? Matched By Old Millie Code? parent_name1  \
# 2609                        False                         NaN          NaN
#
#       parent_name2 parent_whatsapp student_whatsapp parent_whatsapp_cleaned  \
# 2609           NaN             NaN              NaN                     NaN
#
#      student_whatsapp_cleaned parent_parsed_country student_parsed_country
# 2609                      NaN                   NaN                    NaN
#
# [1 rows x 32 columns]

# %%
#df_pattern = pd.read_csv("number3_pattern.csv")

# %%
df_pattern = df_pattern.rename(columns={"Unnamed: 0": "Domain", "Unnamed: 1": "Pattern"})
df_pattern.head()
# Out:
#               Domain Pattern              0              1             2  \
# 0         aus.school   [-2:]        l.lee23      a.emera22  y.alqallaf23
# 1          gmail.com     NaN  scarletkim341  kaushikabinod    taiba.61.c
# 2         jps.edu.sa     NaN        jps0085        jps0825       jps0280
# 3      robcol.k12.tr   [-2:]      metisi.23      tufdog.23     cakemr.24
# 4  dhafraschools.com     NaN         468885         579457        579227
#
#                3                      4                5                6  \
# 0  n.aloraifan23           j.alqallaf24       s.luhaib23   a.abushiekah24
# 1     mahamubi24  sarah.albouss.college  reemhanyelsayed  shahdamohdsalah
# 2        jps0555                jps0096          jps0455          jps0610
# 3      odaani.23              ozdeli.24        karazr.24        ertece.23
# 4         468852                 579203           579202           546852
#
#                   7  ...         988            989                990  \
# 0     a.abougoush24  ...         NaN            NaN                NaN
# 1  farisrealmadread  ...  sebafoti05  charmainetung  ravi.syaputra2006
# 2           jps0360  ...         NaN            NaN                NaN
# 3         unlire.23  ...         NaN            NaN                NaN
# 4            579275  ...         NaN            NaN                NaN
#
#                991               992             993              994  \
# 0              NaN               NaN             NaN              NaN
# 1  eleanorhillwood  lindadeseguragst  degefusamrawit  alimohamedmah17
# 2              NaN               NaN             NaN              NaN
# 3              NaN               NaN             NaN              NaN
# 4              NaN               NaN             NaN              NaN
#
#                 995              996              997
# 0               NaN              NaN              NaN
# 1  zander.vanzyl198  hiba.hassan1911  aldhi.bagaswira
# 2               NaN              NaN              NaN
# 3               NaN              NaN              NaN
# 4               NaN              NaN              NaN
#
# [5 rows x 1000 columns]

# %%
#df_pattern["Pattern"].unique()

# %%
df_pattern["Pattern"].replace("x", np.NaN, inplace = True)

# %%
first_two = df_pattern.loc[df_pattern["Pattern"] == "[:2]"]
last_two = df_pattern.loc[df_pattern["Pattern"] == "[-2:]"]
first_four = df_pattern.loc[df_pattern["Pattern"] == "[4:]"]
last_four = df_pattern.loc[df_pattern["Pattern"] == "[-4:]"]
middle = df_pattern.loc[df_pattern["Pattern"] == "[-4:-2]"]

# %%
new_grad = []

for i in range(len(df["Domain"])):
    # Graduation year lies in first two char
    if df["Domain"][i] in first_two["Domain"].to_list():
        if df["Handle"][i][:2].isnumeric() == True:
            new_grad.append(int("20" + df["Handle"][i][:2]))
        else:
            new_grad.append(df["Grad_Year"][i])
            
    # Graduation year lies in last two char        
    elif df["Domain"][i] in last_two["Domain"].to_list():
        if df["Handle"][i][-2:].isnumeric() == True:
            new_grad.append(int("20" + df["Handle"][i][-2:]))
        else:
            new_grad.append(df["Grad_Year"][i])
            
    # Graduation year lies in first four char          
    elif df["Domain"][i] in first_four["Domain"].to_list():
        if df["Handle"][i][4:].isnumeric() == True:
            new_grad.append(int(df["Handle"][i][4:]))
        else:
            new_grad.append(df["Grad_Year"][i])
    
    # Graduation year lies in last four char  
    elif df["Domain"][i] in last_four["Domain"].to_list():
        if df["Handle"][i][-4:].isnumeric() == True:
            new_grad.append(int(df["Handle"][i][-4:]))
        else:
            new_grad.append(df["Grad_Year"][i])
    
    # Graduation year is the middle char
    elif df["Domain"][i] in middle["Domain"].to_list():
            new_grad.append(int("20" + df["Handle"][i][-4:-2]))
            
    elif df["Domain"][i] == "sherborne.com" or df["Domain"][i] == "wycombeabbey.com":
        if df["Handle"][i][0:2] == "15":
            new_grad.append(2022)
        elif df["Handle"][i][0:2]  == "16":
            new_grad.append(2023)
        elif df["Handle"][i][0:2]  == "17":
            new_grad.append(2024)
            
    else: new_grad.append(df["Grad_Year"][i])

# %%
df["Grad_Year_New"] = new_grad

# %%
# Out:
#         id               name                          email        Handle  \
# 26    3612         Angela Joo        16jooa@wycombeabbey.com        16jooa
# 36     737     Chloe Fangiono   15fangionoc@wycombeabbey.com   15fangionoc
# 64    1234       Amelia Smith      17smitha@wycombeabbey.com      17smitha
# 66    3526          Ellie Yau        16yaue@wycombeabbey.com        16yaue
# 78    1463     Isabella Pucci      17puccii@wycombeabbey.com      17puccii
# 142   2436    Francesca Pucci      15puccif@wycombeabbey.com      15puccif
# 294   1284        Caitlyn Woo        17wooc@wycombeabbey.com        17wooc
# 325   1288           Jade Law        17lawj@wycombeabbey.com        17lawj
# 366    738        Helen Helen  15kurnytskah@wycombeabbey.com  15kurnytskah
# 1122  1196       Anna Trusova    16trusovaa@wycombeabbey.com    16trusovaa
# 1134  1252      Annette Cheah      16cheaha@wycombeabbey.com      16cheaha
# 1142  1289     Liza Kashirina  17kashirinal@wycombeabbey.com  17kashirinal
# 1433  2121   Isabelle Abdulai    16abdulaii@wycombeabbey.com    16abdulaii
# 1438  2135  Michelle Michelle      17nogaim@wycombeabbey.com      17nogaim
#
#                 Domain  Grad_Year  Grad_Year_New         name.1  \
# 26    wycombeabbey.com       2023           2023  Wycombe Abbey
# 36    wycombeabbey.com         -1           2022  Wycombe Abbey
# 64    wycombeabbey.com       2024           2024  Wycombe Abbey
# 66    wycombeabbey.com       2023           2023  Wycombe Abbey
# 78    wycombeabbey.com       2024           2024  Wycombe Abbey
# 142   wycombeabbey.com       2021           2022  Wycombe Abbey
# 294   wycombeabbey.com       2024           2024  Wycombe Abbey
# 325   wycombeabbey.com       2024           2024  Wycombe Abbey
# 366   wycombeabbey.com       2022           2022  Wycombe Abbey
# 1122  wycombeabbey.com       2023           2023  Wycombe Abbey
# 1134  wycombeabbey.com       2021           2023  Wycombe Abbey
# 1142  wycombeabbey.com       2024           2024  Wycombe Abbey
# 1433  wycombeabbey.com         -1           2023  Wycombe Abbey
# 1438  wycombeabbey.com         -1           2024  Wycombe Abbey
#
#          millieCode  Total_Score  ...  Matched By New Millie Code?  \
# 26    MLO-GB-000498       1550.0  ...                         True
# 36    MLO-GB-000498       1520.0  ...                         True
# 64    MLO-GB-000498       1470.0  ...                         True
# 66    MLO-GB-000498       1470.0  ...                         True
# 78    MLO-GB-000498       1450.0  ...                         True
# 142   MLO-GB-000498       1340.0  ...                         True
# 294   MLO-GB-000498       1180.0  ...                         True
# 325   MLO-GB-000498       1150.0  ...                         True
# 366   MLO-GB-000498       1110.0  ...                         True
# 1122  MLO-GB-000498          0.0  ...                         True
# 1134  MLO-GB-000498          0.0  ...                         True
# 1142  MLO-GB-000498          0.0  ...                         True
# 1433  MLO-GB-000498          0.0  ...                         True
# 1438  MLO-GB-000498          0.0  ...                         True
#
#      Matched By Old Millie Code? parent_name1  parent_name2 parent_whatsapp  \
# 26                           NaN      Ahyoung           Lee         #ERROR!
# 36                           NaN          NaN           NaN             NaN
# 64                           NaN         Nick         Smith             NaN
# 66                           NaN         Eric           Yau         #ERROR!
# 78                           NaN      Sabrina       De Caro             NaN
# 142                          NaN      Sabrina       De Caro             NaN
# 294                          NaN        Sonia          Ming             NaN
# 325                          NaN        Randa            Li             NaN
# 366                          NaN     Kateryna     Kurnytska             NaN
# 1122                         NaN       Alexey        Trusov             NaN
# 1134                         NaN    Stephanie         Cheah             NaN
# 1142                         NaN        Elena     Kashirina             NaN
# 1433                         NaN       Nkechi       Abdulai             NaN
# 1438                         NaN     Svetlana         Nogai             NaN
#
#      student_whatsapp parent_whatsapp_cleaned student_whatsapp_cleaned  \
# 26            #ERROR!                     NaN                      NaN
# 36                NaN                     NaN                      NaN
# 64       447713588578                     NaN          +44 7713 588578
# 66     +852 5213 6866                     NaN           +852 5213 6866
# 78       972000000000                     NaN                      NaN
# 142               NaN                     NaN                      NaN
# 294       85295034610                     NaN           +852 9503 4610
# 325      447376090056                     NaN          +44 7376 090056
# 366       47760432839                     NaN                      NaN
# 1122     447565079484                     NaN          +44 7565 079484
# 1134     447445566688                     NaN          +44 7445 566688
# 1142                0                     NaN                      NaN
# 1433     972000000000                     NaN                      NaN
# 1438     447979371140                     NaN          +44 7979 371140
#
#      parent_parsed_country student_parsed_country
# 26                     NaN                    NaN
# 36                     NaN                    NaN
# 64                     NaN         United Kingdom
# 66                     NaN              Hong Kong
# 78                     NaN                    NaN
# 142                    NaN                    NaN
# 294                    NaN              Hong Kong
# 325                    NaN         United Kingdom
# 366                    NaN                    NaN
# 1122                   NaN         United Kingdom
# 1134                   NaN         United Kingdom
# 1142                   NaN                    NaN
# 1433                   NaN                    NaN
# 1438                   NaN         United Kingdom
#
# [14 rows x 32 columns]

# %%
df["Grad_Year"].unique()
df["Grad_Year_New"].unique()
df.insert(7, "Check", "")

# %%
check_lst = []
for i in range(len(df)):
    if df["Grad_Year_New"][i] != df["Grad_Year"][i] or df["Grad_Year_New"][i] == -1:
        check_lst.append("1")
    else:
        check_lst.append("0")

df["Check"] = check_lst

# %%
df.loc[df["Domain"] == "wycombeabbey.com"]
# Out:
#         id               name                          email        Handle  \
# 26    3612         Angela Joo        16jooa@wycombeabbey.com        16jooa
# 36     737     Chloe Fangiono   15fangionoc@wycombeabbey.com   15fangionoc
# 64    1234       Amelia Smith      17smitha@wycombeabbey.com      17smitha
# 66    3526          Ellie Yau        16yaue@wycombeabbey.com        16yaue
# 78    1463     Isabella Pucci      17puccii@wycombeabbey.com      17puccii
# 142   2436    Francesca Pucci      15puccif@wycombeabbey.com      15puccif
# 294   1284        Caitlyn Woo        17wooc@wycombeabbey.com        17wooc
# 325   1288           Jade Law        17lawj@wycombeabbey.com        17lawj
# 366    738        Helen Helen  15kurnytskah@wycombeabbey.com  15kurnytskah
# 1122  1196       Anna Trusova    16trusovaa@wycombeabbey.com    16trusovaa
# 1134  1252      Annette Cheah      16cheaha@wycombeabbey.com      16cheaha
# 1142  1289     Liza Kashirina  17kashirinal@wycombeabbey.com  17kashirinal
# 1433  2121   Isabelle Abdulai    16abdulaii@wycombeabbey.com    16abdulaii
# 1438  2135  Michelle Michelle      17nogaim@wycombeabbey.com      17nogaim
#
#                 Domain  Grad_Year  Grad_Year_New Check         name.1  \
# 26    wycombeabbey.com       2023           2023     0  Wycombe Abbey
# 36    wycombeabbey.com         -1           2022     1  Wycombe Abbey
# 64    wycombeabbey.com       2024           2024     0  Wycombe Abbey
# 66    wycombeabbey.com       2023           2023     0  Wycombe Abbey
# 78    wycombeabbey.com       2024           2024     0  Wycombe Abbey
# 142   wycombeabbey.com       2021           2022     1  Wycombe Abbey
# 294   wycombeabbey.com       2024           2024     0  Wycombe Abbey
# 325   wycombeabbey.com       2024           2024     0  Wycombe Abbey
# 366   wycombeabbey.com       2022           2022     0  Wycombe Abbey
# 1122  wycombeabbey.com       2023           2023     0  Wycombe Abbey
# 1134  wycombeabbey.com       2021           2023     1  Wycombe Abbey
# 1142  wycombeabbey.com       2024           2024     0  Wycombe Abbey
# 1433  wycombeabbey.com         -1           2023     1  Wycombe Abbey
# 1438  wycombeabbey.com         -1           2024     1  Wycombe Abbey
#
#          millieCode  ...  Matched By New Millie Code?  \
# 26    MLO-GB-000498  ...                         True
# 36    MLO-GB-000498  ...                         True
# 64    MLO-GB-000498  ...                         True
# 66    MLO-GB-000498  ...                         True
# 78    MLO-GB-000498  ...                         True
# 142   MLO-GB-000498  ...                         True
# 294   MLO-GB-000498  ...                         True
# 325   MLO-GB-000498  ...                         True
# 366   MLO-GB-000498  ...                         True
# 1122  MLO-GB-000498  ...                         True
# 1134  MLO-GB-000498  ...                         True
# 1142  MLO-GB-000498  ...                         True
# 1433  MLO-GB-000498  ...                         True
# 1438  MLO-GB-000498  ...                         True
#
#       Matched By Old Millie Code? parent_name1 parent_name2  parent_whatsapp  \
# 26                            NaN      Ahyoung          Lee          #ERROR!
# 36                            NaN          NaN          NaN              NaN
# 64                            NaN         Nick        Smith              NaN
# 66                            NaN         Eric          Yau          #ERROR!
# 78                            NaN      Sabrina      De Caro              NaN
# 142                           NaN      Sabrina      De Caro              NaN
# 294                           NaN        Sonia         Ming              NaN
# 325                           NaN        Randa           Li              NaN
# 366                           NaN     Kateryna    Kurnytska              NaN
# 1122                          NaN       Alexey       Trusov              NaN
# 1134                          NaN    Stephanie        Cheah              NaN
# 1142                          NaN        Elena    Kashirina              NaN
# 1433                          NaN       Nkechi      Abdulai              NaN
# 1438                          NaN     Svetlana        Nogai              NaN
#
#      student_whatsapp parent_whatsapp_cleaned student_whatsapp_cleaned  \
# 26            #ERROR!                     NaN                      NaN
# 36                NaN                     NaN                      NaN
# 64       447713588578                     NaN          +44 7713 588578
# 66     +852 5213 6866                     NaN           +852 5213 6866
# 78       972000000000                     NaN                      NaN
# 142               NaN                     NaN                      NaN
# 294       85295034610                     NaN           +852 9503 4610
# 325      447376090056                     NaN          +44 7376 090056
# 366       47760432839                     NaN                      NaN
# 1122     447565079484                     NaN          +44 7565 079484
# 1134     447445566688                     NaN          +44 7445 566688
# 1142                0                     NaN                      NaN
# 1433     972000000000                     NaN                      NaN
# 1438     447979371140                     NaN          +44 7979 371140
#
#      parent_parsed_country student_parsed_country
# 26                     NaN                    NaN
# 36                     NaN                    NaN
# 64                     NaN         United Kingdom
# 66                     NaN              Hong Kong
# 78                     NaN                    NaN
# 142                    NaN                    NaN
# 294                    NaN              Hong Kong
# 325                    NaN         United Kingdom
# 366                    NaN                    NaN
# 1122                   NaN         United Kingdom
# 1134                   NaN         United Kingdom
# 1142                   NaN                    NaN
# 1433                   NaN                    NaN
# 1438                   NaN         United Kingdom
#
# [14 rows x 33 columns]

# %%
df.to_csv("Number3_Check.csv")
