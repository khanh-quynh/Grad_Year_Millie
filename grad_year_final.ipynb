# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("grad_year.xlsx")

# %%
df.head()
# Out:
#      id               name                            email Grad_Year  \
# 0  2900       Thuy Tien Ha              tinkaha05@gmail.com      2023
# 1  2916   Jakub Strzelczyk      jakubstrzelczyk04@gmail.com      2022
# 2  2847    Oliwia CieÅ›lak         oliwiathao2016@gmail.com      2023
# 3  2896  Julia Golebiewska  julia.golebiewska1203@gmail.com      2023
# 4  2914    Alicja Cichocka       alicjacichocka04@gmail.com      2023
#
#                                  name.1     millieCode  Total_Score  \
# 0  33 Liceum im. M. Kopernika, Warszawa  IBO-PL-000703       1500.0
# 1  33 Liceum im. M. Kopernika, Warszawa  IBO-PL-000703       1450.0
# 2  33 Liceum im. M. Kopernika, Warszawa  IBO-PL-000703       1440.0
# 3  33 Liceum im. M. Kopernika, Warszawa  IBO-PL-000703       1330.0
# 4  33 Liceum im. M. Kopernika, Warszawa  IBO-PL-000703       1320.0
#
#    Multiple_Attempts_At_Test?           Parent_Name  \
# 0                        True        Thi Thuy Ha Ho
# 1                        True  Agnieszka Strzelczyk
# 2                       False     Anh Trinh Thi Kim
# 3                        True  Malgorzata Skubiszak
# 4                       False       Tomasz Cichocki
#
#                       Parent Email  ...  Matched By New Millie Code?  \
# 0          hothithuyha67@gmail.com  ...                         True
# 1             aga.strzelczyk@wp.pl  ...                         True
# 2             handang919@gmail.com  ...                         True
# 3  julia.golebiewska1203@gmail.com  ...                         True
# 4        tomasz.cichocki@gmail.com  ...                         True
#
#   Matched By Old Millie Code? parent_name1   parent_name2 parent_whatsapp  \
# 0                         NaN  Thi Thuy Ha             Ho             NaN
# 1                         NaN    Agnieszka     Strzelczyk             NaN
# 2                         NaN          Anh  Trinh Thi Kim             NaN
# 3                         NaN   Malgorzata      Skubiszak             NaN
# 4                         NaN       Tomasz       Cichocki             NaN
#
#   student_whatsapp parent_parsed_country student_parsed_country  \
# 0  +48 665 269 569                   NaN                     PL
# 1  +48 506 720 450                   NaN                     PL
# 2      48739599243                   NaN                     PL
# 3  +48 601 690 696                   NaN                     PL
# 4  +48 731 604 161                   NaN                     PL
#
#   parent_whatsapp_cleaned  student_whatsapp_cleaned
# 0                     NaN           +48 665 269 569
# 1                     NaN           +48 506 720 450
# 2                     NaN           +48 739 599 243
# 3                     NaN           +48 601 690 696
# 4                     NaN           +48 731 604 161
#
# [5 rows x 29 columns]

# %%
df["Grad_Year"].replace(np.NaN, -1, inplace = True)
df["Grad_Year"].replace("None", -1, inplace = True)

# %% [markdown]
# count = 0
# for i in df["Grad_Year"]:
#     if i == -1:
#         count += 1
# print(count)

# %%
df.insert(4,'Grad_Year_New',"")

# %%
email_dict = {}
email_lst = df['email'].to_list()

handle_lst = []
domain_lst = []
for i in range(len(email_lst)):
    email = str(email_lst[i])
    e = email.split('@')
    handle, domain = e[0], e[-1]
    handle_lst.append(handle)
    domain_lst.append(domain)
    
    if domain not in email_dict:
        email_dict[domain] = []
    email_dict[domain].append(handle)

# %%
df.insert(3, "Handle", handle_lst)
df.insert(4, "Domain", domain_lst)

# %%
df_email = pd.DataFrame.from_dict(email_dict, orient = 'index')
df_email.head()
# Out:
#                          0                  1                2     \
# gmail.com           tinkaha05  jakubstrzelczyk04   oliwiathao2016
# spychalski.pl             max               None             None
# outlook.com      do_halamalis    rashed3176ahmad  rashed3176ahmed
# wp.pl          izusia.dziekan               None             None
# abaoman.org      gkorisepati1           isharma1        anadamal1
#
#                                 3                 4              5     \
# gmail.com      julia.golebiewska1203  alicjacichocka04     mkania2006
# spychalski.pl                   None              None           None
# outlook.com          fatmasultan7070   omaralmasry2006  alisha-taibek
# wp.pl                           None              None           None
# abaoman.org                  zahmed2      ktiriveedhi1     agiridhar1
#
#                              6              7             8     \
# gmail.com      tarkowska.antonina       eambrzyk      fidoalek
# spychalski.pl                None           None          None
# outlook.com      farah.m.shawareb  turquolicious        imrwaa
# wp.pl                        None           None          None
# abaoman.org           lalmaskari1    iakomolede1  vmanivannan1
#
#                             9     ...           1884         1885  \
# gmail.com      wiktoriagorska.pl  ...  cychanmelissa  daflight540
# spychalski.pl               None  ...           None         None
# outlook.com             cdelolmo  ...           None         None
# wp.pl                       None  ...           None         None
# abaoman.org             mwadidi1  ...           None         None
#
#                        1886              1887               1888       1889  \
# gmail.com      abhisri.dash  mariam.alattar05  nicole.aboudaher7  6263sadaf
# spychalski.pl          None              None               None       None
# outlook.com            None              None               None       None
# wp.pl                  None              None               None       None
# abaoman.org            None              None               None       None
#
#                        1890           1891             1892         1893
# gmail.com      bhumimotiani  nabihanajam29  norahannalex.05  firedemisey
# spychalski.pl          None           None             None         None
# outlook.com            None           None             None         None
# wp.pl                  None           None             None         None
# abaoman.org            None           None             None         None
#
# [5 rows x 1894 columns]

# %%
#df_email.to_csv("email_df.csv") #stop here

# %%
df_pattern = pd.read_csv("grad_year_pattern.csv")

# %%
df_pattern = df_pattern.rename(columns={"Unnamed: 0": "Domain", "Unnamed: 1": "Pattern"})
df_pattern.head()
# Out:
#           Domain Pattern               0                  1                2  \
# 0      gmail.com       x       tinkaha05  jakubstrzelczyk04   oliwiathao2016
# 1  spychalski.pl       x             max                NaN              NaN
# 2    outlook.com       x    do_halamalis    rashed3176ahmad  rashed3176ahmed
# 3          wp.pl       x  izusia.dziekan                NaN              NaN
# 4    abaoman.org       x    gkorisepati1           isharma1        anadamal1
#
#                        3                 4              5                   6  \
# 0  julia.golebiewska1203  alicjacichocka04     mkania2006  tarkowska.antonina
# 1                    NaN               NaN            NaN                 NaN
# 2        fatmasultan7070   omaralmasry2006  alisha-taibek    farah.m.shawareb
# 3                    NaN               NaN            NaN                 NaN
# 4                zahmed2      ktiriveedhi1     agiridhar1         lalmaskari1
#
#                7  ...            988              989            990  \
# 0       eambrzyk  ...  isiah.gossaye  lieselisimbi222  willaishimwe8
# 1            NaN  ...            NaN              NaN            NaN
# 2  turquolicious  ...            NaN              NaN            NaN
# 3            NaN  ...            NaN              NaN            NaN
# 4    iakomolede1  ...            NaN              NaN            NaN
#
#              991             992       993             994        995  \
# 0  tetagatete123  samazanoella31  kabonu12  hara.moraitaki  houralafi
# 1            NaN             NaN       NaN             NaN        NaN
# 2            NaN             NaN       NaN             NaN        NaN
# 3            NaN             NaN       NaN             NaN        NaN
# 4            NaN             NaN       NaN             NaN        NaN
#
#               996        997
# 0  bdralshatti2k4  saalajeel
# 1             NaN        NaN
# 2             NaN        NaN
# 3             NaN        NaN
# 4             NaN        NaN
#
# [5 rows x 1000 columns]

# %%
df_pattern["Pattern"].unique()
# Out:
# array(['x', '[:2]', '[-2:]', '[-4:-2]', '07 = 2022, 08 = 2023', '[-4:]',
#        '[:4]', '16 = 2023'], dtype=object)

# %%
df_pattern["Pattern"].replace("x", np.NaN, inplace = True)

# %%
first_two = df_pattern.loc[df_pattern["Pattern"] == "[:2]"]
last_two = df_pattern.loc[df_pattern["Pattern"] == "[-2:]"]
first_four = df_pattern.loc[df_pattern["Pattern"] == "[4:]"]
last_four = df_pattern.loc[df_pattern["Pattern"] == "[-4:]"]
middle = df_pattern.loc[df_pattern["Pattern"] == "[-4:-2]"]

# %%
new_grad = []

for i in range(len(df["Domain"])):
    # Graduation year lies in first two char
    if df["Domain"][i] in first_two["Domain"].to_list():
        if df["Handle"][i][:2].isnumeric() == True:
            new_grad.append(int("20" + df["Handle"][i][:2]))
        else:
            new_grad.append(df["Grad_Year"][i])
            
    # Graduation year lies in last two char        
    elif df["Domain"][i] in last_two["Domain"].to_list():
        if df["Handle"][i][-2:].isnumeric() == True:
            new_grad.append(int("20" + df["Handle"][i][-2:]))
        else:
            new_grad.append(df["Grad_Year"][i])
            
    # Graduation year lies in first four char          
    elif df["Domain"][i] in first_four["Domain"].to_list():
        if df["Handle"][i][4:].isnumeric() == True:
            new_grad.append(int(df["Handle"][i][4:]))
        else:
            new_grad.append(df["Grad_Year"][i])
    
    # Graduation year lies in last four char  
    elif df["Domain"][i] in last_four["Domain"].to_list():
        if df["Handle"][i][-4:].isnumeric() == True:
            new_grad.append(int(df["Handle"][i][-4:]))
        else:
            new_grad.append(df["Grad_Year"][i])
    
    # Graduation year is the middle char
    elif df["Domain"][i] in middle["Domain"].to_list():
            new_grad.append(int("20" + df["Handle"][i][-4:-2]))
            
    elif df["Domain"][i] == "sherborne.com" or df["Domain"][i] == "wycombeabbey.com":
        if df["Handle"][i][0:2] == "15":
            new_grad.append(2022)
        elif df["Handle"][i][0:2]  == "16":
            new_grad.append(2023)
        elif df["Handle"][i][0:2]  == "17":
            new_grad.append(2024)
            
    else: new_grad.append(df["Grad_Year"][i])

# %%
df["Grad_Year_New"] = new_grad

# %%
df.loc[df["Domain"] == "wycombeabbey.com"]
# Out:
#         id               name                          email        Handle  \
# 3231  3612         Angela Joo        16jooa@wycombeabbey.com        16jooa
# 3232   737     Chloe Fangiono   15fangionoc@wycombeabbey.com   15fangionoc
# 3233  1234       Amelia Smith      17smitha@wycombeabbey.com      17smitha
# 3234  3526          Ellie Yau        16yaue@wycombeabbey.com        16yaue
# 3235  1463     Isabella Pucci      17puccii@wycombeabbey.com      17puccii
# 3236  2436    Francesca Pucci      15puccif@wycombeabbey.com      15puccif
# 3237  1284        Caitlyn Woo        17wooc@wycombeabbey.com        17wooc
# 3238  1288           Jade Law        17lawj@wycombeabbey.com        17lawj
# 3239   738        Helen Helen  15kurnytskah@wycombeabbey.com  15kurnytskah
# 3242  1196       Anna Trusova    16trusovaa@wycombeabbey.com    16trusovaa
# 3243  1252      Annette Cheah      16cheaha@wycombeabbey.com      16cheaha
# 3244  1289     Liza Kashirina  17kashirinal@wycombeabbey.com  17kashirinal
# 3247  2121   Isabelle Abdulai    16abdulaii@wycombeabbey.com    16abdulaii
# 3249  2135  Michelle Michelle      17nogaim@wycombeabbey.com      17nogaim
#
#                 Domain  Grad_Year  Grad_Year_New         name.1  \
# 3231  wycombeabbey.com       2023           2023  Wycombe Abbey
# 3232  wycombeabbey.com         -1           2022  Wycombe Abbey
# 3233  wycombeabbey.com       2024           2024  Wycombe Abbey
# 3234  wycombeabbey.com       2023           2023  Wycombe Abbey
# 3235  wycombeabbey.com       2024           2024  Wycombe Abbey
# 3236  wycombeabbey.com       2021           2022  Wycombe Abbey
# 3237  wycombeabbey.com       2024           2024  Wycombe Abbey
# 3238  wycombeabbey.com       2024           2024  Wycombe Abbey
# 3239  wycombeabbey.com       2022           2022  Wycombe Abbey
# 3242  wycombeabbey.com       2023           2023  Wycombe Abbey
# 3243  wycombeabbey.com       2021           2023  Wycombe Abbey
# 3244  wycombeabbey.com       2024           2024  Wycombe Abbey
# 3247  wycombeabbey.com         -1           2023  Wycombe Abbey
# 3249  wycombeabbey.com         -1           2024  Wycombe Abbey
#
#          millieCode  Total_Score  ...  Matched By New Millie Code?  \
# 3231  MLO-GB-000498       1550.0  ...                         True
# 3232  MLO-GB-000498       1520.0  ...                         True
# 3233  MLO-GB-000498       1470.0  ...                         True
# 3234  MLO-GB-000498       1470.0  ...                         True
# 3235  MLO-GB-000498       1450.0  ...                         True
# 3236  MLO-GB-000498       1340.0  ...                         True
# 3237  MLO-GB-000498       1180.0  ...                         True
# 3238  MLO-GB-000498       1150.0  ...                         True
# 3239  MLO-GB-000498       1110.0  ...                         True
# 3242  MLO-GB-000498          0.0  ...                         True
# 3243  MLO-GB-000498          0.0  ...                         True
# 3244  MLO-GB-000498          0.0  ...                         True
# 3247  MLO-GB-000498          0.0  ...                         True
# 3249  MLO-GB-000498          0.0  ...                         True
#
#      Matched By Old Millie Code? parent_name1  parent_name2 parent_whatsapp  \
# 3231                         NaN      Ahyoung           Lee         #ERROR!
# 3232                         NaN          NaN           NaN             NaN
# 3233                         NaN         Nick         Smith             NaN
# 3234                         NaN         Eric           Yau         #ERROR!
# 3235                         NaN      Sabrina       De Caro             NaN
# 3236                         NaN      Sabrina       De Caro             NaN
# 3237                         NaN        Sonia          Ming             NaN
# 3238                         NaN        Randa            Li             NaN
# 3239                         NaN     Kateryna     Kurnytska             NaN
# 3242                         NaN       Alexey        Trusov             NaN
# 3243                         NaN    Stephanie         Cheah             NaN
# 3244                         NaN        Elena     Kashirina             NaN
# 3247                         NaN       Nkechi       Abdulai             NaN
# 3249                         NaN     Svetlana         Nogai             NaN
#
#      student_whatsapp parent_parsed_country student_parsed_country  \
# 3231          #ERROR!                   NaN                    NaN
# 3232              NaN                   NaN                    NaN
# 3233     447713588578                   NaN                     GB
# 3234   +852 5213 6866                   NaN                     HK
# 3235     972000000000                   NaN                    NaN
# 3236              NaN                   NaN                    NaN
# 3237      85295034610                   NaN                     HK
# 3238     447376090056                   NaN                     GB
# 3239      47760432839                   NaN                    NaN
# 3242     447565079484                   NaN                     GB
# 3243     447445566688                   NaN                     GB
# 3244                0                   NaN                    NaN
# 3247     972000000000                   NaN                    NaN
# 3249     447979371140                   NaN                     GB
#
#      parent_whatsapp_cleaned student_whatsapp_cleaned
# 3231                     NaN                      NaN
# 3232                     NaN                      NaN
# 3233                     NaN          +44 7713 588578
# 3234                     NaN           +852 5213 6866
# 3235                     NaN                      NaN
# 3236                     NaN                      NaN
# 3237                     NaN           +852 9503 4610
# 3238                     NaN          +44 7376 090056
# 3239                     NaN                      NaN
# 3242                     NaN          +44 7565 079484
# 3243                     NaN          +44 7445 566688
# 3244                     NaN                      NaN
# 3247                     NaN                      NaN
# 3249                     NaN          +44 7979 371140
#
# [14 rows x 32 columns]

# %%
df["Grad_Year"].unique()
df["Grad_Year_New"].unique()
# Out:
# array([2023, 2022, 2024, 2021, 2025,   -1, 2020])

# %%
check_lst = []
for i in range(len(df)):
    if df["Grad_Year_New"][i] != df["Grad_Year"][i] or df["Grad_Year_New"][i] == -1:
        check_lst.append("1")
    else:
        check_lst.append("0")

df.insert(7, "Check", check_lst)

# %%
df.head()
# Out:
#      id               name                            email  \
# 0  2900       Thuy Tien Ha              tinkaha05@gmail.com
# 1  2916   Jakub Strzelczyk      jakubstrzelczyk04@gmail.com
# 2  2847    Oliwia CieÅ›lak         oliwiathao2016@gmail.com
# 3  2896  Julia Golebiewska  julia.golebiewska1203@gmail.com
# 4  2914    Alicja Cichocka       alicjacichocka04@gmail.com
#
#                   Handle     Domain  Grad_Year  Grad_Year_New Check  \
# 0              tinkaha05  gmail.com       2023           2023     0
# 1      jakubstrzelczyk04  gmail.com       2022           2022     0
# 2         oliwiathao2016  gmail.com       2023           2023     0
# 3  julia.golebiewska1203  gmail.com       2023           2023     0
# 4       alicjacichocka04  gmail.com       2023           2023     0
#
#                                  name.1     millieCode  ...  \
# 0  33 Liceum im. M. Kopernika, Warszawa  IBO-PL-000703  ...
# 1  33 Liceum im. M. Kopernika, Warszawa  IBO-PL-000703  ...
# 2  33 Liceum im. M. Kopernika, Warszawa  IBO-PL-000703  ...
# 3  33 Liceum im. M. Kopernika, Warszawa  IBO-PL-000703  ...
# 4  33 Liceum im. M. Kopernika, Warszawa  IBO-PL-000703  ...
#
#    Matched By New Millie Code?  Matched By Old Millie Code? parent_name1  \
# 0                         True                          NaN  Thi Thuy Ha
# 1                         True                          NaN    Agnieszka
# 2                         True                          NaN          Anh
# 3                         True                          NaN   Malgorzata
# 4                         True                          NaN       Tomasz
#
#     parent_name2  parent_whatsapp student_whatsapp parent_parsed_country  \
# 0             Ho              NaN  +48 665 269 569                   NaN
# 1     Strzelczyk              NaN  +48 506 720 450                   NaN
# 2  Trinh Thi Kim              NaN      48739599243                   NaN
# 3      Skubiszak              NaN  +48 601 690 696                   NaN
# 4       Cichocki              NaN  +48 731 604 161                   NaN
#
#   student_parsed_country parent_whatsapp_cleaned student_whatsapp_cleaned
# 0                     PL                     NaN          +48 665 269 569
# 1                     PL                     NaN          +48 506 720 450
# 2                     PL                     NaN          +48 739 599 243
# 3                     PL                     NaN          +48 601 690 696
# 4                     PL                     NaN          +48 731 604 161
#
# [5 rows x 33 columns]

# %%
df.loc[df["Domain"] == "bayanschool.edu.bh"]
# Out:
#         id                          name  \
# 802   2783                  Ali Al Jeshi
# 804    263                Ali Al Maraghi
# 805   2725                Manaf AlHaddad
# 806    311              Leyana Al Dajani
# 807    388                Ayah Al Daaysi
# 808   2720  MOHAMED BIN KHALIFA ALGHATAM
# 809   2723                 Arwa Al Amadi
# 811   2767                  Mada Alsaati
# 812   2793             Abdulla Buhammood
# 813    462                Yara Bin Thani
# 814    268             Sharifa Al Mannai
# 815    307                Mariam Alalawi
# 816    535            Khalifa Al Khalifa
# 817    256          Al Hanouf Al Mubarak
# 818    305             Abdulla Aldhawadi
# 819    260                 Shaikha Majed
# 820    580                 Hamza Shahzad
# 822    371               Laith Algosaibi
# 823    326             Mohamed Alromaihi
# 825    464             Mohammed Alghanem
# 826    532                Rashid Alhajri
# 827    536         Abdullrhman Alghayesh
# 828    635                 Yousif Haqiqi
# 829    709              Bandar Alkhayyer
# 830    843             Hiba Abdulghaffar
# 832   2367              Yousif Altoorani
# 834   2383              Bayan Al Mahmeed
# 3609   284            Khalifa Al Khalifa
# 3610   286                Yara Bin Thani
# 3622   335                 Hamza Shahzad
# 3634   386            Mohammed  AlGhanem
#
#                                        email               Handle  \
# 802        a.aljishi.2396@bayanschool.edu.bh       a.aljishi.2396
# 804      a.almaraghi.2375@bayanschool.edu.bh     a.almaraghi.2375
# 805       m.alhaddad.2222@bayanschool.edu.bh      m.alhaddad.2222
# 806       l.aldajani.2349@bayanschool.edu.bh      l.aldajani.2349
# 807       a.aldaaysi.2494@bayanschool.edu.bh      a.aldaaysi.2494
# 808      m.alghattam.2370@bayanschool.edu.bh     m.alghattam.2370
# 809       a.alammadi.2301@bayanschool.edu.bh      a.alammadi.2301
# 811        m.alsaati.2360@bayanschool.edu.bh       m.alsaati.2360
# 812      a.buhammood.2392@bayanschool.edu.bh     a.buhammood.2392
# 813       y.binthani.2366@bayanschool.edu.bh      y.binthani.2366
# 814       s.almannai.2345@bayanschool.edu.bh      s.almannai.2345
# 815        m.alalawi.2348@bayanschool.edu.bh       m.alalawi.2348
# 816      k.alkhalifa.2334@bayanschool.edu.bh     k.alkhalifa.2334
# 817      a.almubarak.2372@bayanschool.edu.bh     a.almubarak.2372
# 818      a.althawadi.2321@bayanschool.edu.bh     a.althawadi.2321
# 819        s.almajed.2340@bayanschool.edu.bh       s.almajed.2340
# 820         h.shazad.2225@bayanschool.edu.bh        h.shazad.2225
# 822      l.algosaibi.2233@bayanschool.edu.bh     l.algosaibi.2233
# 823      m.alromaihi.2363@bayanschool.edu.bh     m.alromaihi.2363
# 825       m.alghanem.2326@bayanschool.edu.bh      m.alghanem.2326
# 826      r.aljumairi.2279@bayanschool.edu.bh     r.aljumairi.2279
# 827       a.alghaysh.2300@bayanschool.edu.bh      a.alghaysh.2300
# 828         Y.Haqiqi.2190@bayanschool.edu.bh        Y.Haqiqi.2190
# 829      B.Alkhayyer.2212@bayanschool.edu.bh     B.Alkhayyer.2212
# 830   h.abdulghaffar.2210@bayanschool.edu.bh  h.abdulghaffar.2210
# 832      y.altoorani.2236@bayanschool.edu.bh     y.altoorani.2236
# 834      b.almahmeed.2227@bayanschool.edu.bh     b.almahmeed.2227
# 3609     K.alkhalifa.2334@bayanschool.edu.bh     K.alkhalifa.2334
# 3610      Y.BinThani.2366@bayanschool.edu.bh      Y.BinThani.2366
# 3622       h.shazhad.2225@bayanschool.edu.bh       h.shazhad.2225
# 3634      M.AlGhanem.2326@bayanschool.edu.bh      M.AlGhanem.2326
#
#                   Domain  Grad_Year  Grad_Year_New Check  \
# 802   bayanschool.edu.bh       2023           2023     0
# 804   bayanschool.edu.bh         -1           2023     1
# 805   bayanschool.edu.bh       2022           2022     0
# 806   bayanschool.edu.bh         -1           2023     1
# 807   bayanschool.edu.bh         -1           2024     1
# 808   bayanschool.edu.bh       2023           2023     0
# 809   bayanschool.edu.bh       2023           2023     0
# 811   bayanschool.edu.bh       2023           2023     0
# 812   bayanschool.edu.bh       2023           2023     0
# 813   bayanschool.edu.bh         -1           2023     1
# 814   bayanschool.edu.bh         -1           2023     1
# 815   bayanschool.edu.bh         -1           2023     1
# 816   bayanschool.edu.bh         -1           2023     1
# 817   bayanschool.edu.bh         -1           2023     1
# 818   bayanschool.edu.bh         -1           2023     1
# 819   bayanschool.edu.bh         -1           2023     1
# 820   bayanschool.edu.bh         -1           2022     1
# 822   bayanschool.edu.bh         -1           2022     1
# 823   bayanschool.edu.bh         -1           2023     1
# 825   bayanschool.edu.bh         -1           2023     1
# 826   bayanschool.edu.bh         -1           2022     1
# 827   bayanschool.edu.bh         -1           2023     1
# 828   bayanschool.edu.bh         -1           2021     1
# 829   bayanschool.edu.bh         -1           2022     1
# 830   bayanschool.edu.bh         -1           2022     1
# 832   bayanschool.edu.bh       2022           2022     0
# 834   bayanschool.edu.bh       2022           2022     0
# 3609  bayanschool.edu.bh         -1           2023     1
# 3610  bayanschool.edu.bh         -1           2023     1
# 3622  bayanschool.edu.bh         -1           2022     1
# 3634  bayanschool.edu.bh         -1           2023     1
#
#                     name.1     millieCode  ...  Matched By New Millie Code?  \
# 802   Bahrain Bayan School  IBO-BH-000707  ...                         True
# 804   Bahrain Bayan School  IBO-BH-000707  ...                         True
# 805   Bahrain Bayan School  IBO-BH-000707  ...                         True
# 806   Bahrain Bayan School  IBO-BH-000707  ...                         True
# 807   Bahrain Bayan School  IBO-BH-000707  ...                         True
# 808   Bahrain Bayan School  IBO-BH-000707  ...                         True
# 809   Bahrain Bayan School  IBO-BH-000707  ...                         True
# 811   Bahrain Bayan School  IBO-BH-000707  ...                         True
# 812   Bahrain Bayan School  IBO-BH-000707  ...                         True
# 813   Bahrain Bayan School            NaN  ...                        False
# 814   Bahrain Bayan School            NaN  ...                        False
# 815   Bahrain Bayan School            NaN  ...                        False
# 816   Bahrain Bayan School            NaN  ...                        False
# 817   Bahrain Bayan School            NaN  ...                        False
# 818   Bahrain Bayan School            NaN  ...                        False
# 819   Bahrain Bayan School            NaN  ...                        False
# 820   Bahrain Bayan School            NaN  ...                        False
# 822   Bahrain Bayan School            NaN  ...                        False
# 823   Bahrain Bayan School            NaN  ...                        False
# 825   Bahrain Bayan School            NaN  ...                        False
# 826   Bahrain Bayan School            NaN  ...                        False
# 827   Bahrain Bayan School            NaN  ...                        False
# 828   Bahrain Bayan School            NaN  ...                        False
# 829   Bahrain Bayan School            NaN  ...                        False
# 830   Bahrain Bayan School            NaN  ...                        False
# 832   Bahrain Bayan School            NaN  ...                        False
# 834   Bahrain Bayan School            NaN  ...                        False
# 3609                   NaN            NaN  ...                        False
# 3610                   NaN            NaN  ...                        False
# 3622                   NaN            NaN  ...                        False
# 3634                   NaN            NaN  ...                        False
#
#       Matched By Old Millie Code?       parent_name1 parent_name2  \
# 802                           NaN               Mona     Al Hamad
# 804                           NaN                NaN          NaN
# 805                           NaN              Osama     AlHaddad
# 806                           NaN                NaN          NaN
# 807                           NaN                NaN          NaN
# 808                           NaN  KHALIFA BIN AHMED     ALGHATAM
# 809                           NaN            Ebtisam       Maroof
# 811                           NaN              Suzan         Safa
# 812                           NaN               Duaa      Sharafi
# 813                           NaN                NaN          NaN
# 814                           NaN                NaN          NaN
# 815                           NaN                NaN          NaN
# 816                           NaN                NaN          NaN
# 817                           NaN                NaN          NaN
# 818                           NaN                NaN          NaN
# 819                           NaN                NaN          NaN
# 820                           NaN                NaN          NaN
# 822                           NaN                NaN          NaN
# 823                           NaN                NaN          NaN
# 825                           NaN                NaN          NaN
# 826                           NaN                NaN          NaN
# 827                           NaN                NaN          NaN
# 828                           NaN                NaN          NaN
# 829                           NaN                NaN          NaN
# 830                           NaN                NaN          NaN
# 832                           NaN              Abeer        Baqer
# 834                           NaN             Naeema     Budhaish
# 3609                        False                NaN          NaN
# 3610                        False                NaN          NaN
# 3622                        False                NaN          NaN
# 3634                        False                NaN          NaN
#
#       parent_whatsapp student_whatsapp parent_parsed_country  \
# 802               NaN   +973 3211 3364                   NaN
# 804               NaN              NaN                   NaN
# 805               NaN   +973 3432 1129                   NaN
# 806               NaN              NaN                   NaN
# 807               NaN              NaN                   NaN
# 808               NaN   +973 3214 1461                   NaN
# 809               NaN   +973 3968 0459                   NaN
# 811               NaN   +973 3699 3500                   NaN
# 812               NaN   +973 3939 1166                   NaN
# 813               NaN              NaN                   NaN
# 814               NaN              NaN                   NaN
# 815               NaN              NaN                   NaN
# 816               NaN              NaN                   NaN
# 817               NaN              NaN                   NaN
# 818               NaN              NaN                   NaN
# 819               NaN              NaN                   NaN
# 820               NaN              NaN                   NaN
# 822               NaN              NaN                   NaN
# 823               NaN              NaN                   NaN
# 825               NaN              NaN                   NaN
# 826               NaN              NaN                   NaN
# 827               NaN              NaN                   NaN
# 828               NaN              NaN                   NaN
# 829               NaN              NaN                   NaN
# 830               NaN              NaN                   NaN
# 832               NaN              NaN                   NaN
# 834               NaN              NaN                   NaN
# 3609              NaN              NaN                   NaN
# 3610              NaN              NaN                   NaN
# 3622              NaN              NaN                   NaN
# 3634              NaN              NaN                   NaN
#
#      student_parsed_country parent_whatsapp_cleaned student_whatsapp_cleaned
# 802                      BH                     NaN           +973 3211 3364
# 804                     NaN                     NaN                      NaN
# 805                      BH                     NaN           +973 3432 1129
# 806                     NaN                     NaN                      NaN
# 807                     NaN                     NaN                      NaN
# 808                      BH                     NaN           +973 3214 1461
# 809                      BH                     NaN           +973 3968 0459
# 811                      BH                     NaN           +973 3699 3500
# 812                      BH                     NaN           +973 3939 1166
# 813                     NaN                     NaN                      NaN
# 814                     NaN                     NaN                      NaN
# 815                     NaN                     NaN                      NaN
# 816                     NaN                     NaN                      NaN
# 817                     NaN                     NaN                      NaN
# 818                     NaN                     NaN                      NaN
# 819                     NaN                     NaN                      NaN
# 820                     NaN                     NaN                      NaN
# 822                     NaN                     NaN                      NaN
# 823                     NaN                     NaN                      NaN
# 825                     NaN                     NaN                      NaN
# 826                     NaN                     NaN                      NaN
# 827                     NaN                     NaN                      NaN
# 828                     NaN                     NaN                      NaN
# 829                     NaN                     NaN                      NaN
# 830                     NaN                     NaN                      NaN
# 832                     NaN                     NaN                      NaN
# 834                     NaN                     NaN                      NaN
# 3609                    NaN                     NaN                      NaN
# 3610                    NaN                     NaN                      NaN
# 3622                    NaN                     NaN                      NaN
# 3634                    NaN                     NaN                      NaN
#
# [31 rows x 33 columns]

# %%
df.to_csv("Grad_Year_Check.csv")
